# %%
import pandas

# %%
file = "../data/2019_censcomercialbcn_detall.csv"

df = pandas.read_csv(file)

new_df = df[['Codi_Principal_Activitat', 'Nom_Principal_Activitat', 'Codi_Sector_Activitat', 'Nom_Sector_Activitat', 'Codi_Grup_Activitat', 'Nom_Grup_Activitat', 'Nom_Local', 'SN_Oci_Nocturn', 'SN_Obert24h', 'SN_Carrer', 'Nom_Mercat', 'Nom_Galeria', 'Nom_CComercial', 'Direccio_Unica', 'Codi_Via', 'Nom_Via', 'Codi_Barri', 'Nom_Barri', 'Codi_Districte', 'Nom_Districte']]
# Out:
# C:\Users\Angel\AppData\Local\Temp\ipykernel_12292\2816647579.py:3: DtypeWarning: Columns (35,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pandas.read_csv(file)

# %%
new_df.head()
# Out:
#    Codi_Principal_Activitat Nom_Principal_Activitat  Codi_Sector_Activitat  \
# 0                         1                   Actiu                      2
# 1                         1                   Actiu                      2
# 2                         1                   Actiu                      2
# 3                         1                   Actiu                      3
# 4                         1                   Actiu                      2
#
#   Nom_Sector_Activitat  Codi_Grup_Activitat Nom_Grup_Activitat  \
# 0              Serveis                   16             Altres
# 1              Serveis                   16             Altres
# 2              Serveis                   16             Altres
# 3               Altres                   17             Altres
# 4              Serveis                   16             Altres
#
#                  Nom_Local  SN_Oci_Nocturn  SN_Obert24h  SN_Carrer Nom_Mercat  \
# 0                  SORIGUE               1            1          0        NaN
# 1       CEJIDOS SIVILA S.A               1            1          0        NaN
# 2          QUALITY ESPRESO               1            1          0        NaN
# 3                      CLD               1            1          0        NaN
# 4  CATALANA DEL BUTANO,S.A               1            1          0        NaN
#
#   Nom_Galeria Nom_CComercial           Direccio_Unica  Codi_Via Nom_Via  \
# 0         NaN            NaN    222206, 19-19, LOC 10    222206  MOTORS
# 1         NaN            NaN  222206, 278-282, LOC 10    222206  MOTORS
# 2         NaN            NaN      222206, 1-9, LOC 10    222206  MOTORS
# 3         NaN            NaN    222206, 21-21, LOC 10    222206  MOTORS
# 4         NaN            NaN    222206, 25-27, LOC 10    222206  MOTORS
#
#    Codi_Barri                   Nom_Barri  Codi_Districte   Nom_Districte
# 0          12  la Marina del Prat Vermell               3  Sants-Montjuïc
# 1          12  la Marina del Prat Vermell               3  Sants-Montjuïc
# 2          12  la Marina del Prat Vermell               3  Sants-Montjuïc
# 3          12  la Marina del Prat Vermell               3  Sants-Montjuïc
# 4          12  la Marina del Prat Vermell               3  Sants-Montjuïc

# %%
new_df.describe()
# Out:
#        Codi_Principal_Activitat  Codi_Sector_Activitat  Codi_Grup_Activitat  \
# count              80554.000000           80554.000000         80554.000000
# mean                   0.764183               2.221019             7.946942
# std                    0.424511               1.090387             6.822455
# min                    0.000000               1.000000             0.000000
# 25%                    1.000000               1.000000             1.000000
# 50%                    1.000000               2.000000             7.000000
# 75%                    1.000000               3.000000            15.000000
# max                    1.000000               5.000000            17.000000
#
#        SN_Oci_Nocturn   SN_Obert24h     SN_Carrer       Codi_Via  \
# count    80554.000000  80554.000000  80554.000000   80554.000000
# mean         0.997095      0.996673      0.042456  199124.310152
# std          0.053819      0.057584      0.201628  130662.647977
# min          0.000000      0.000000      0.000000     306.000000
# 25%          1.000000      1.000000      0.000000   94605.000000
# 50%          1.000000      1.000000      0.000000  189100.000000
# 75%          1.000000      1.000000      0.000000  288703.000000
# max          1.000000      1.000000      1.000000  701818.000000
#
#          Codi_Barri  Codi_Districte
# count  80554.000000    80554.000000
# mean      29.549023        5.187191
# std       22.272671        3.056172
# min        1.000000        1.000000
# 25%        9.000000        2.000000
# 50%       26.000000        5.000000
# 75%       46.000000        8.000000
# max       73.000000       10.000000

# %%
new_df.shape
# Out:
# (80554, 20)

# %%
new_df["Nom_Principal_Activitat"].unique()
# Out:
# array(['Actiu', 'Sense activitat Econòmica'], dtype=object)

# %%
new_df["Nom_Sector_Activitat"].unique()
# Out:
# array(['Serveis', 'Altres', 'Comerç al detall', 'Sense informació',
#        'Sense informació - Havia tingut activitat (rètol)', 'En reforma',
#        'Locals buits en venda i lloguer', 'Locals buits en lloguer',
#        'Locals buits en venda', 'Comerç al detall /Engròs'], dtype=object)

# %%
new_df["Nom_Grup_Activitat"].unique()
# Out:
# array(['Altres', 'Automoció',
#        'Restaurants, bars i hotels (Inclòs hostals, pensions i fondes)',
#        'Parament de la llar', 'Quotidià alimentari',
#        'Quotidià no alimentari', 'Equipament personal', 'Ensenyament',
#        'Grup no definit', 'Reparacions (Electrodomèstics i automòbils)',
#        'Sanitat i assistència', 'Finances i assegurances',
#        'Equipaments culturals i recreatius', 'Activitats immobiliàries',
#        'Oci i cultura', 'Manteniment, neteja i producció'], dtype=object)
